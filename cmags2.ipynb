# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="ticks", color_codes=True)

# %%
df= pd.read_csv("vgsales.csv")
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# max       10.570000     82.740000

# %%
df.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
#Dropping all NaN values (there are no unknown numeric values. All NaN values come from the categorical data.)
df=df.dropna()
df.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
type_of_games = df.groupby('Genre')['Publisher'].nunique().plot(kind='bar')
type_of_games .set_ylabel("Num of Games")
type_of_games .set_xlabel("Genre")
# Out:
# Text(0.5,0,'Genre')

# %%
## Comparing sales across the different Genres
sns.relplot(x="NA_Sales", y="Genre", data=df);
#plt.savefig('NA_Sles.png')
sns.relplot(x="EU_Sales", y="Genre", data=df);
#plt.savefig('EU_Sales.png')
sns.relplot(x="Other_Sales", y="Genre", data=df);
#plt.savefig('Other_Sales.png')
sns.relplot(x="Global_Sales", y="Genre", data=df);
#plt.savefig('Global_Sales.png')

# %%
##From the graphs we can see that sports have the highest amount of sales
#lets keep digging and figure out what that outlier is

# %%
#Digging into sports 
df_Sports = df.loc[df['Genre']=="Sports"]
len(df_Sports)
df_Sports
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 3          4                                  Wii Sports Resort      Wii
# 13        14                                            Wii Fit      Wii
# 14        15                                       Wii Fit Plus      Wii
# 77        78                                            FIFA 16      PS4
# 85        86                 Mario & Sonic at the Olympic Games      Wii
# 112      113                                            FIFA 14      PS3
# 117      118                                      Zumba Fitness      Wii
# 121      122                                            FIFA 12      PS3
# 124      125                                            FIFA 15      PS4
# 139      140                                      Kinect Sports     X360
# 189      190                 Mario & Sonic at the Olympic Games       DS
# 199      200                                     FIFA Soccer 11      PS3
# 202      203                             Tony Hawk's Pro Skater       PS
# 211      212                                      Madden NFL 06      PS2
# 219      220                                            FIFA 15      PS3
# 221      222                                            FIFA 17      PS4
# 225      226                           Tony Hawk's Pro Skater 2       PS
# 233      234          Mario & Sonic at the Olympic Winter Games      Wii
# 238      239                                    Madden NFL 2005      PS2
# 240      241                                      Madden NFL 07      PS2
# 248      249                           Tony Hawk's Pro Skater 3      PS2
# 249      250          Winning Eleven: Pro Evolution Soccer 2007      PS2
# 256      257                                            FIFA 14     X360
# 269      270                                     FIFA Soccer 06      PS2
# 275      276                                            FIFA 12     X360
# 279      280                                    Madden NFL 2003      PS2
# 283      284                                     FIFA Soccer 07      PS2
# 292      293                      World Soccer Winning Eleven 9      PS2
# 298      299                                               Golf      NES
# ...      ...                                                ...      ...
# 16218  16221                                      Family Jockey      Wii
# 16226  16229                                      Victory Spike       PS
# 16258  16261                          Championship Manager 2010       PC
# 16292  16295                                          Surf's Up       GC
# 16351  16354                       World Snooker Challenge 2005      PSP
# 16353  16356                                   G1 Jockey 4 2008      PS3
# 16359  16362                                            NHL 2K7       XB
# 16385  16388                         John Daly's ProStroke Golf     X360
# 16389  16392            WSC REAL 09: World Snooker Championship     X360
# 16390  16393                    World Snooker Championship 2007     X360
# 16391  16394                                        Handball 16     X360
# 16395  16398                                   LMA Manager 2007     X360
# 16400  16403                          Pro Evolution Soccer 2010       PC
# 16418  16421  Tennis no Oji-Sama: Doubles no Oji-Sama - Boys...       DS
# 16420  16423          Winning Eleven: Pro Evolution Soccer 2007       PC
# 16576      0.00         0.00          0.01
# 16578      0.00         0.00          0.01
# 16579      0.00         0.00          0.01
# 16581      0.00         0.00          0.01
# 16587      0.01         0.00          0.01
#
# [2304 rows x 11 columns]

# %%
#That one outlier is Wii Sports

# %%
##Trying to figure out who the most popular publisher is
df.groupby('Platform')['Publisher'].nunique().plot(kind='bar')

# %%
#Which platform makes the most sales?
plt.figure(figsize=(12,24))
sns.swarmplot(x="NA_Sales", y="Platform", data=df_Sports);
    #plt.savefig('NA_Sles_Sports.png')
sns.swarmplot(x="EU_Sales", y="Platform", data=df_Sports);
    #plt.savefig('EU_Sales_Sports.png')
sns.swarmplot(x="Global_Sales", y="Platform", data=df_Sports);
    #plt.savefig('Global_Sales_Sports.png')

# %%
global_sales_publisher = df.pivot_table(index=['Publisher'], values=['Other_Sales','NA_Sales','EU_Sales','JP_Sales'], 
                                           aggfunc=np.sum).sort_values(['Other_Sales'], ascending=False)
global_sales_publisher = global_sales_publisher[['NA_Sales','Other_Sales','EU_Sales','JP_Sales']]
ax = global_sales_publisher.iloc[0:10,:].plot(kind='bar', stacked=True, grid=True)
ax.set_title('Top 10 Publishers by Global Sales', size=25, color='blue', alpha=0.5)
ax.set_xlabel('Publisher', size=25, color='green', alpha=0.5)
ax.set_ylabel('Sales', size=25, color='green', alpha=0.5)
# Out:
# Text(0,0.5,'Sales')

# %%
df
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 1          2                                  Super Mario Bros.      NES
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 4          5                           Pokemon Red/Pokemon Blue       GB
# 5          6                                             Tetris       GB
# 6          7                              New Super Mario Bros.       DS
# 7          8                                           Wii Play      Wii
# 8          9                          New Super Mario Bros. Wii      Wii
# 9         10                                          Duck Hunt      NES
# 10        11                                         Nintendogs       DS
# 11        12                                      Mario Kart DS       DS
# 12        13                        Pokemon Gold/Pokemon Silver       GB
# 13        14                                            Wii Fit      Wii
# 14        15                                       Wii Fit Plus      Wii
# 15        16                                 Kinect Adventures!     X360
# 16        17                                 Grand Theft Auto V      PS3
# 17        18                      Grand Theft Auto: San Andreas      PS2
# 18        19                                  Super Mario World     SNES
# 19        20       Brain Age: Train Your Brain in Minutes a Day       DS
# 20        21                      Pokemon Diamond/Pokemon Pearl       DS
# 21        22                                   Super Mario Land       GB
# 22        23                                Super Mario Bros. 3      NES
# 23        24                                 Grand Theft Auto V     X360
# 24        25                        Grand Theft Auto: Vice City      PS2
# 25        26                      Pokemon Ruby/Pokemon Sapphire      GBA
# 26        27                        Pokemon Black/Pokemon White       DS
# 27        28        Brain Age 2: More Training in Minutes a Day       DS
# 28        29                             Gran Turismo 3: A-Spec      PS2
# 29        30                     Call of Duty: Modern Warfare 3     X360
# ...      ...                                                ...      ...
# 16568  16571                                        XI Coliseum      PSP
# 16569  16572                                 Resident Evil 4 HD     XOne
# 16570  16573                      Farming 2017 - The Simulation      PS4
# 16571  16574         Grisaia no Kajitsu: La Fruit de la Grisaia      PSP
# 16572  16575                   Scarlett: Nichijou no Kyoukaisen      PS2
# 16573  16576                                Mini Desktop Racing      Wii
# 16574  16577  Yattaman Wii: BikkuriDokkiri Machine de Mou Ra...      Wii
# 16575  16578                              Neo Angelique Special      PSP
# 16576  16579                                  Rugby Challenge 3     XOne
# 16577  16580                                          Damnation       PC
# 16578  16581                      Outdoors Unleashed: Africa 3D      3DS
# 16579  16582                                  PGA European Tour      N64
# 16580  16583                                          Real Rode      PS2
# 16581  16584                                          Fit & Fun      Wii
# 16582  16585                                    Planet Monsters      GBA
# 16583  16586                                     Carmageddon 64      N64
# 16584  16587                                   Bust-A-Move 3000       GC
# 16585  16588                                             Breach       PC
# 16586  16589                     Secret Files 2: Puritas Cordis       DS
# 16587  16590                           Mezase!! Tsuri Master DS       DS
# 16588  16591                                   Mega Brain Boost       DS
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
# 16590  16593  Eiyuu Densetsu: Sora no Kiseki Material Collec...      PSP
# 16591  16594                                Myst IV: Revelation       PC
# 16592  16595                                           Plushees       DS
# 16593  16596                 Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                      Men in Black II: Alien Escape       GC
# 16595  16598   SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                         Know How 2       DS
# 16597  16600                                   Spirits & Spells      GBA
#
#          Year         Genre                    Publisher  NA_Sales  EU_Sales  \
# 0      2006.0        Sports                     Nintendo     41.49     29.02
# 1      1985.0      Platform                     Nintendo     29.08      3.58
# 2      2008.0        Racing                     Nintendo     15.85     12.88
# 3      2009.0        Sports                     Nintendo     15.75     11.01
# 4      1996.0  Role-Playing                     Nintendo     11.27      8.89
# 5      1989.0        Puzzle                     Nintendo     23.20      2.26
# 6      2006.0      Platform                     Nintendo     11.38      9.23
# 7      2006.0          Misc                     Nintendo     14.03      9.20
# 8      2009.0      Platform                     Nintendo     14.59      7.06
# 9      1984.0       Shooter                     Nintendo     26.93      0.63
# 10     2005.0    Simulation                     Nintendo      9.07     11.00
# 11     2005.0        Racing                     Nintendo      9.81      7.57
# 12     1999.0  Role-Playing                     Nintendo      9.00      6.18
# 13     2007.0        Sports                     Nintendo      8.94      8.03
# 14     2009.0        Sports                     Nintendo      9.09      8.59
# 15     2010.0          Misc       Microsoft Game Studios     14.97      4.94
# 16     2013.0        Action         Take-Two Interactive      7.01      9.27
# 17     2004.0        Action         Take-Two Interactive      9.43      0.40
# 18     1990.0      Platform                     Nintendo     12.78      3.75
# 19     2005.0          Misc                     Nintendo      4.75      9.26
# 20     2006.0  Role-Playing                     Nintendo      6.42      4.52
# 21     1989.0      Platform                     Nintendo     10.83      2.71
# 22     1988.0      Platform                     Nintendo      9.54      3.44
# 23     2013.0        Action         Take-Two Interactive      9.63      5.31
# 24     2002.0        Action         Take-Two Interactive      8.41      5.49
# 25     2002.0  Role-Playing                     Nintendo      6.06      3.90
# 26     2010.0  Role-Playing                     Nintendo      5.57      3.28
# 27     2005.0        Puzzle                     Nintendo      3.44      5.36
# 28     2001.0        Racing  Sony Computer Entertainment      6.85      5.09
# 29     2011.0       Shooter                   Activision      9.03      4.28
# ...       ...           ...                          ...       ...       ...
# 16568  2006.0        Puzzle  Sony Computer Entertainment      0.00      0.00
# 16569  2016.0       Shooter                       Capcom      0.01      0.00
# 16570  2016.0    Simulation            UIG Entertainment      0.00      0.01
# 16571  2013.0     Adventure                    Prototype      0.00      0.00
# 16572  2008.0     Adventure              Kadokawa Shoten      0.00      0.00
# 16573  2007.0        Racing               Popcorn Arcade      0.01      0.00
# 16574  2008.0        Racing                  Takara Tomy      0.00      0.00
# 16575  2008.0     Adventure                   Tecmo Koei      0.00      0.00
# 16576  2016.0        Sports         Alternative Software      0.00      0.01
# 16577  2009.0       Shooter                  Codemasters      0.00      0.01
# 16578  2011.0        Sports                      Mastiff      0.01      0.00
# 16579  2000.0        Sports                   Infogrames      0.01      0.00
# 16580  2008.0     Adventure              Kadokawa Shoten      0.00      0.00
# 16581  2011.0        Sports                      Unknown      0.00      0.01
# 16582  2001.0        Action                        Titus      0.01      0.00
# 16583  1999.0        Action           Virgin Interactive      0.01      0.00
# 16584  2003.0        Puzzle                      Ubisoft      0.01      0.00
# 16585  2011.0       Shooter                    Destineer      0.01      0.00
# 16586  2009.0     Adventure                  Deep Silver      0.00      0.01
# 16587  2009.0        Sports                  Hudson Soft      0.00      0.00
# 16588  2008.0        Puzzle        Majesco Entertainment      0.01      0.00
# 16589  2016.0        Action              dramatic create      0.00      0.00
# 16590  2007.0  Role-Playing           Falcom Corporation      0.00      0.00
# 16591  2004.0     Adventure                      Ubisoft      0.01      0.00
# 16592  2008.0    Simulation                    Destineer      0.01      0.00
# 16593  2002.0      Platform                        Kemco      0.01      0.00
# 16594  2003.0       Shooter                   Infogrames      0.01      0.00
# 16595  2008.0        Racing                   Activision      0.00      0.00
# 16596  2010.0        Puzzle                     7G//AMES      0.00      0.01
# 16597  2003.0      Platform                      Wanadoo      0.01      0.00
#
#        JP_Sales  Other_Sales  Global_Sales
# 0          3.77         8.46         82.74
# 1          6.81         0.77         40.24
# 2          3.79         3.31         35.82
# 3          3.28         2.96         33.00
# 4         10.22         1.00         31.37
# 5          4.22         0.58         30.26
# 6          6.50         2.90         30.01
# 7          2.93         2.85         29.02
# 8          4.70         2.26         28.62
# 9          0.28         0.47         28.31
# 10         1.93         2.75         24.76
# 11         4.13         1.92         23.42
# 12         7.20         0.71         23.10
# 13         3.60         2.15         22.72
# 14         2.53         1.79         22.00
# 15         0.24         1.67         21.82
# 16         0.97         4.14         21.40
# 17         0.41        10.57         20.81
# 18         3.54         0.55         20.61
# 19         4.16         2.05         20.22
# 20         6.04         1.37         18.36
# 21         4.18         0.42         18.14
# 22         3.84         0.46         17.28
# 23         0.06         1.38         16.38
# 24         0.47         1.78         16.15
# 25         5.38         0.50         15.85
# 26         5.65         0.82         15.32
# 27         5.32         1.18         15.30
# 28         1.87         1.16         14.98
# 29         0.13         1.32         14.76
# ...         ...          ...           ...
# 16568      0.01         0.00          0.01
# 16569      0.00         0.00          0.01
# 16570      0.00         0.00          0.01
# 16571      0.01         0.00          0.01
# 16572      0.01         0.00          0.01
# 16573      0.00         0.00          0.01
# 16574      0.01         0.00          0.01
# 16575      0.01         0.00          0.01
# 16576      0.00         0.00          0.01
# 16577      0.00         0.00          0.01
# 16578      0.00         0.00          0.01
# 16579      0.00         0.00          0.01
# 16580      0.01         0.00          0.01
# 16581      0.00         0.00          0.01
# 16582      0.00         0.00          0.01
# 16583      0.00         0.00          0.01
# 16584      0.00         0.00          0.01
# 16585      0.00         0.00          0.01
# 16586      0.00         0.00          0.01
# 16587      0.01         0.00          0.01
# 16588      0.00         0.00          0.01
# 16589      0.01         0.00          0.01
# 16590      0.01         0.00          0.01
# 16591      0.00         0.00          0.01
# 16592      0.00         0.00          0.01
# 16593      0.00         0.00          0.01
# 16594      0.00         0.00          0.01
# 16595      0.00         0.00          0.01
# 16596      0.00         0.00          0.01
# 16597      0.00         0.00          0.01
#
# [16291 rows x 11 columns]

# %%
top_10 = df[:10:]
top_10
sns.relplot(x="Name", y="Global_Sales", height=5, aspect=5, kind="line", data=top_10)

# %%
dfs = df.sort_values("Year", axis = 0, ascending = True,inplace = True, na_position ='last')
print(df.Genre.unique())
##All Genres
sns.relplot(x="Year", y="Global_Sales", kind="line", data=df)
#plt.savefig('pop_all.png')
# Out:
# ['Misc' 'Fighting' 'Action' 'Shooter' 'Sports' 'Platform' 'Simulation'
#  'Racing' 'Puzzle' 'Adventure' 'Role-Playing' 'Strategy']
# C:\Users\Avinash Ratnam\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#With only sports 
#df_sports = df.loc[df['Genre']=="Sports"]
sns.relplot(x="Year", y="Global_Sales", kind="line", data=df_Sports)
#plt.savefig('pop_Sports.png')
print("Number of  Sports games made = ", len(df_Sports))
# Out:
# C:\Users\Avinash Ratnam\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Number of  Sports games made =  2304

# %%
#With only Misc 
df_Misc = df.loc[df['Genre']=="Misc"]
sns.relplot(x="Year", y="Global_Sales", kind="line", data=df_Misc)
#plt.savefig('pop_Misc.png')
print("Number of  Miscellaneous games made = ", len(df_Misc))
# Out:
# C:\Users\Avinash Ratnam\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Number of  Miscellaneous games made =  1739

# %%
#With only Fighting 
df_Fighting = df.loc[df['Genre']=="Fighting"]
sns.relplot(x="Year", y="Global_Sales", kind="line", data=df_Fighting)
#plt.savefig('pop_Fighting.png')
print("Number of  Fighting games made = ", len(df_Fighting))
# Out:
# C:\Users\Avinash Ratnam\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Number of  Fighting games made =  836

# %%
#With only Action 
df_Action = df.loc[df['Genre']=="Action"]
sns.relplot(x="Year", y="Global_Sales", kind="line", data=df_Action)
#plt.savefig('pop_Action.png')
print("Number of  Action games made = ", len(df_Action))
# Out:
# C:\Users\Avinash Ratnam\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Number of  Action games made =  3251

# %%
#With only Shooter 
df_Shooter = df.loc[df['Genre']=="Shooter"]
sns.relplot(x="Year", y="Global_Sales", kind="line", data=df_Shooter)
#plt.savefig('pop_Shooter.png')
print("Number of Shooter games made = ", len(df_Shooter))
# Out:
# C:\Users\Avinash Ratnam\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Number of Shooter games made =  1282

# %%
#With only Puzzle
df_Puzzle = df.loc[df['Genre']=="Puzzle"]
sns.relplot(x="Year", y="Global_Sales", kind="line", data=df_Puzzle)
#plt.savefig('pop_Puzzle.png')
print("Number of Puzzle games made = ", len(df_Puzzle))
# Out:
# C:\Users\Avinash Ratnam\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Number of Puzzle games made =  570

# %%
#With only Platform
df_Platform = df.loc[df['Genre']=="Platform"]
sns.relplot(x="Year", y="Global_Sales", kind="line", data=df_Platform)
#plt.savefig('pop_Platform.png')
print("Number of Platform games made = ", len(df_Platform))
# Out:
# C:\Users\Avinash Ratnam\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Number of Platform games made =  875

# %%
#With only Simulation
df_Simulation = df.loc[df['Genre']=="Simulation"]
sns.relplot(x="Year", y="Global_Sales", kind="line", data=df_Simulation)
#plt.savefig('pop_Simulation.png')
print("Number of Simulation games made = ", len(df_Simulation))
# Out:
# C:\Users\Avinash Ratnam\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Number of Simulation games made =  848

# %%
#With only Racing
df_Racing = df.loc[df['Genre']=="Racing"]
sns.relplot(x="Year", y="Global_Sales", kind="line", data=df_Racing)
#plt.savefig('pop_Racing.png')
print("Number of Racing games made = ", len(df_Racing))
# Out:
# C:\Users\Avinash Ratnam\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Number of Racing games made =  1225

# %%
#With only Adventure
df_Adventure = df.loc[df['Genre']=="Adventure"]
sns.relplot(x="Year", y="Global_Sales", kind="line", data=df_Adventure)
#plt.savefig('pop_Adventure.png')
print("Number of Adventure games made = ", len(df_Adventure))
# Out:
# C:\Users\Avinash Ratnam\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Number of Adventure games made =  1274

# %%
#With only Role-Playing
df_RolePlaying = df.loc[df['Genre']=="Role-Playing"]
sns.relplot(x="Year", y="Global_Sales", kind="line", data=df_RolePlaying)
#plt.savefig('pop_Role-Playing.png')
print("Number of RolePlaying games made = ", len(df_RolePlaying))
# Out:
# C:\Users\Avinash Ratnam\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Number of RolePlaying games made =  1470

# %%
#With only Strategy
df_Strategy = df.loc[df['Genre']=="Strategy"]
sns.relplot(x="Year", y="Global_Sales", kind="line", data=df_Strategy)
#plt.savefig('pop_Strategy.png')
print("Number of Strategy games made = ", len(df_Strategy))
# Out:
# C:\Users\Avinash Ratnam\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
#
# 16429  2016.0  Simulation                    Koch Media      0.00      0.01
# 7812   2016.0  Simulation         Marvelous Interactive      0.00      0.00
# 15684  2016.0  Simulation                    Tecmo Koei      0.00      0.00
# 16344  2016.0  Simulation           Paradox Development      0.00      0.01
# 14966  2016.0  Simulation                      Astragon      0.00      0.02
# 14968  2016.0  Simulation                      Nintendo      0.00      0.02
# 10954  2016.0  Simulation            Namco Bandai Games      0.00      0.00
# 5957   2020.0  Simulation                       Ubisoft      0.27      0.00
#
#        JP_Sales  Other_Sales  Global_Sales
# 4346       0.00         0.00          0.45
# 14335      0.00         0.01          0.03
# 14507      0.00         0.01          0.03
# 1792       0.48         0.02          1.14
# 855        0.75         0.04          1.98
# 8575       0.16         0.00          0.16
# 765        0.00         0.10          2.14
# 7929       0.19         0.00          0.19
# 3505       0.13         0.04          0.57
# 6229       0.28         0.00          0.28
# 2289       0.91         0.00          0.91
# 4522       0.43         0.00          0.43
# 11281      0.08         0.00          0.08
# 6368       0.27         0.00          0.27
# 7947       0.00         0.01          0.19
# 950        0.52         0.05          1.83
# 9207       0.00         0.01          0.14
# 4074       0.49         0.00          0.49
# 12385      0.06         0.00          0.06
# 11675      0.00         0.00          0.08
# 13458      0.04         0.00          0.04
# 3443       0.55         0.04          0.58
# 11254      0.08         0.00          0.08
# 10905      0.00         0.01          0.09
# 11529      0.04         0.01          0.08
# 7837       0.19         0.00          0.19
# 13802      0.04         0.00          0.04
# 15479      0.02         0.00          0.02
# 4303       0.00         0.03          0.46
# 12649      0.06         0.00          0.06
# ...         ...          ...           ...
# 12405      0.06         0.00          0.06
# 15961      0.00         0.00          0.02
# 11804      0.00         0.01          0.07
# 15193      0.02         0.00          0.02
# 8747       0.00         0.01          0.15
# 5759       0.00         0.02          0.31
# 8856       0.10         0.01          0.15
# 16072      0.01         0.00          0.01
# 4273       0.00         0.07          0.46
# 5882       0.05         0.04          0.30
# 4704       0.00         0.04          0.41
# 5332       0.00         0.05          0.35
# 14810      0.03         0.00          0.03
# 7768       0.00         0.01          0.19
# 476        1.39         0.12          2.98
# 13836      0.00         0.00          0.04
# 7832       0.00         0.02          0.19
# 13930      0.00         0.00          0.04
# 9230       0.00         0.01          0.14
# 15897      0.00         0.00          0.02
# 16570      0.00         0.00          0.01
# 15415      0.00         0.00          0.02
# 16429      0.00         0.00          0.01
# 7812       0.19         0.00          0.19
# 15684      0.02         0.00          0.02
# 16344      0.00         0.00          0.01
# 14966      0.00         0.00          0.02
# 14968      0.00         0.00          0.02
# 10954      0.09         0.00          0.09
# 5957       0.00         0.02          0.29
#
# [848 rows x 11 columns]

# %%
data = {'Name':['Sports','Misc','Fighting','Action','Shooter','Sports','Puzzle','Platform','Simulation','Racing','Adventure','RolePlaying','Strategy'],'size':[len(df_Sports),len(df_Misc),len(df_Fighting),len(df_Action),len(df_Shooter),len(df_Sports),len(df_Puzzle),len(df_Platform),len(df_Simulation),len(df_Racing),len(df_Adventure),len(df_RolePlaying),len(df_Strategy)]}
df = pd.DataFrame(data)
sns.catplot(x="size", y="Name", kind="bar", data=df)
#plt.savefig('size.png')
plt.xlabel('Number of Games Sold', fontsize=15)
plt.ylabel('Genre', fontsize=15)
# Out:
# C:\Users\Avinash Ratnam\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(-36.7,0.5,'Genre')

# %%
#Action is the most popular Genre

# %%
#Frequency plot for Platform - to find the most popular Platform (plot against Global Sales)
df2=pd.read_csv("vgsales.csv")
df2=df2.dropna()
df2['Platform'].value_counts().plot(kind='barh', grid=True)
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)

# %%
platform_title = df2.Platform.value_counts(sort=True)
plt.subplots(figsize=(10,7))
ax = sns.barplot(x=platform_title , y=platform_title .index, palette='cubehelix')
ax.set_title('Most Number Titles per Platform', color='red', alpha=0.5, size=25)
ax.set_xlabel('Total Title', color='green', alpha=0.5, size=30)
ax.set_ylabel('Platform', color='green', alpha=0.5, size=30)
# Out:
# Text(0,0.5,'Platform')

# %%
platform_title = df2.Platform.value_counts(sort=True)[:2]
plt.subplots(figsize=(10,7))
ax = sns.barplot(x=platform_title , y=platform_title .index, palette='cubehelix')
ax.set_title('Most Number Titles per Platform', color='red', alpha=0.5, size=25)
ax.set_xlabel('Total Title', color='green', alpha=0.5, size=30)
ax.set_ylabel('Platform', color='green', alpha=0.5, size=30)
# Out:
# Text(0,0.5,'Platform')

# %%
#DS and PS2 seem to have the same number of Titles

# %%
#Let's see which one sells better

# %%
global_pub = df2.pivot_table(index=['Platform'], values=['Other_Sales','NA_Sales','EU_Sales','JP_Sales'],
                                          aggfunc=np.sum).sort_values(['Other_Sales'], ascending=False)
global_pub = global_pub[['NA_Sales','Other_Sales','EU_Sales','JP_Sales']]
ax = global_pub.iloc[0:10,:].plot(kind='bar', stacked=True, grid=True)
ax.set_title('Top 10 Consoles by Total Sales', size=25, color='red', alpha=0.5)
ax.set_xlabel('Console', size=25, color='green', alpha=0.5)
ax.set_ylabel('Sales', size=25, color='green', alpha=0.5)
# Out:
# Text(0,0.5,'Sales')

# %%
#PS2 sells better

# %%
#Since PS2 has the most sales, does that mean Sony (the Publisher of PS2) is the best publisher in terms of sales?

# %%
global_sales_publisher = df2.pivot_table(index=['Publisher'], values=['Other_Sales','NA_Sales','EU_Sales','JP_Sales'], 
                                           aggfunc=np.sum).sort_values(['Other_Sales'], ascending=False)
global_sales_publisher = global_sales_publisher[['NA_Sales','Other_Sales','EU_Sales','JP_Sales']]
ax = global_sales_publisher.iloc[0:10,:].plot(kind='bar', stacked=True, grid=True)
ax.set_title('Top 10 Publishers by Global Sales', size=25, color='blue', alpha=0.5)
ax.set_xlabel('Publisher', size=25, color='green', alpha=0.5)
ax.set_ylabel('Sales', size=25, color='green', alpha=0.5)
# Out:
# Text(0,0.5,'Sales')

# %%
#Even though PS2 sells better than DS, Nintendo has higher sales than Sony. Why?

# %%
#Nintendo has a high proportion of Japan Sales compared to the other Publishers

# %%
#sns.set(rc={'figure.figsize':(50,15)})
#sns.scatterplot(x ='Publisher', y ='JP_Sales', data = df2)

# %%
sns.set(rc={'figure.figsize':(20,10)})
sns.scatterplot(x ='Platform', y ='JP_Sales', data = df2)

# %%
#GB seems to have one outlier, with a sales value drastically larger than the others

# %%
df_GB = df2.loc[df2['Platform']=="GB"]

# %%
# 4794   1997.0  Role-Playing                     Imagineer      0.00      0.00
# 4954   2001.0  Role-Playing                     Banpresto      0.00      0.00
# 4983   1998.0      Platform                      Nintendo      0.00      0.00
# 5033   1991.0  Role-Playing                    SquareSoft      0.00      0.00
# 5154   1997.0      Strategy           ASCII Entertainment      0.00      0.00
# 5272   1996.0        Puzzle                      Nintendo      0.00      0.00
# 5493   1990.0        Sports            Namco Bandai Games      0.00      0.00
# 5632   1995.0        Puzzle                      Nintendo      0.00      0.00
# 12670  1991.0        Action  Konami Digital Entertainment      0.00      0.00
#
#        JP_Sales  Other_Sales  Global_Sales
# 4         10.22         1.00         31.37
# 132        1.29         0.99          6.39
# 12         7.20         0.71         23.10
# 30         3.12         0.59         14.64
# 5          4.22         0.58         30.26
# 21         4.18         0.42         18.14
# 391        0.59         0.40          3.41
# 455        0.55         0.34          3.07
# 50         2.69         0.29         11.18
# 736        0.34         0.23          2.20
# 200        0.15         0.22          5.07
# 170        2.00         0.20          5.34
# 171        1.01         0.16          5.31
# 184        1.57         0.15          5.19
# 744        0.30         0.13          2.19
# 318        0.54         0.13          3.83
# 728        0.45         0.13          2.22
# 305        1.07         0.11          3.91
# 191        1.70         0.11          5.13
# 335        1.38         0.10          3.70
# 672        0.40         0.08          2.35
# 1028       0.10         0.07          1.73
# 889        0.20         0.07          1.93
# 923        0.41         0.06          1.86
# 894        0.41         0.06          1.92
# 1710       0.44         0.06          1.18
# 1473       0.01         0.05          1.33
# 880        0.55         0.05          1.94
# 743        1.10         0.05          2.19
# 670        1.48         0.05          2.36
# ...         ...          ...           ...
# 9865       0.12         0.00          0.12
# 11799      0.07         0.00          0.07
# 11816      0.07         0.00          0.07
# 5942       0.30         0.00          0.30
# 12101      0.07         0.00          0.07
# 6155       0.28         0.00          0.28
# 3599       0.56         0.00          0.56
# 5828       0.30         0.00          0.30
# 2798       0.73         0.00          0.73
# 1191       1.56         0.00          1.56
# 1542       1.28         0.00          1.28
# 1856       1.10         0.00          1.10
# 1858       1.10         0.00          1.10
# 2336       0.89         0.00          0.89
# 2490       0.83         0.00          0.83
# 2531       0.81         0.00          0.81
# 2674       0.77         0.00          0.77
# 2727       0.76         0.00          0.76
# 3271       0.62         0.00          0.62
# 5716       0.31         0.00          0.31
# 3695       0.54         0.00          0.54
# 4794       0.40         0.00          0.40
# 4954       0.39         0.00          0.39
# 4983       0.38         0.00          0.38
# 5033       0.38         0.00          0.38
# 5154       0.37         0.00          0.37
# 5272       0.35         0.00          0.35
# 5493       0.33         0.00          0.33
# 5632       0.32         0.00          0.32
# 12670      0.06         0.00          0.06
#
# [97 rows x 11 columns]

# %%
#That one outlier is Pokemon Red/Blue

# %%
sony = df2.loc[df2['Publisher']=="Sony Computer Entertainment"]
na_sales_sum=sony['NA_Sales'].sum()
eu_sales_sum=sony['EU_Sales'].sum()
jp_sales_sum=sony['JP_Sales'].sum()
other_sales_sum=sony['Other_Sales'].sum()
total_sales_sum=sony['Global_Sales'].sum()
type(na_sales_sum)
pie_df=pd.DataFrame({'regional_sales':[na_sales_sum,eu_sales_sum,jp_sales_sum,other_sales_sum]},index=['NA','EU','JP','Other']);
plot = pie_df.plot.pie(y='regional_sales', figsize=(5, 5))
plt.show()
sales_per_year = sony.groupby('Year')['Global_Sales'].nunique().plot(kind='bar')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-46fcc764900d> in <module>()
# ----> 1 sony = df2.loc[df2['Publisher']=="Sony Computer Entertainment"]
#       2 na_sales_sum=sony['NA_Sales'].sum()
#       3 eu_sales_sum=sony['EU_Sales'].sum()
#       4 jp_sales_sum=sony['JP_Sales'].sum()
#       5 other_sales_sum=sony['Other_Sales'].sum()
#
# NameError: name 'df2' is not defined

# %%
nintendo=df2.loc[df2['Publisher']=="Nintendo"]
na_sales_sum=nintendo['NA_Sales'].sum()
eu_sales_sum=nintendo['EU_Sales'].sum()
jp_sales_sum=nintendo['JP_Sales'].sum()
other_sales_sum=nintendo['Other_Sales'].sum()
total_sales_sum=nintendo['Global_Sales'].sum()
pie_df=pd.DataFrame({'regional_sales':[na_sales_sum,eu_sales_sum,jp_sales_sum,other_sales_sum]},index=['NA','EU','JP','Other']);
plot = pie_df.plot.pie(y='regional_sales', figsize=(5, 5))
plt.show()
sales_per_year = sony.groupby('Year')['Global_Sales'].nunique().plot(kind='bar')
plt.show()

# %%
#Most of Nintendo's market is in North America
#Globally, Nintendo sold the most number of units in 2005

# %%
ea=df2.loc[df2['Publisher']=="Electronic Arts"]
na_sales_sum=ea['NA_Sales'].sum()
eu_sales_sum=ea['EU_Sales'].sum()
jp_sales_sum=ea['JP_Sales'].sum()
other_sales_sum=ea['Other_Sales'].sum()
total_sales_sum=ea['Global_Sales'].sum()
pie_df=pd.DataFrame({'regional_sales':[na_sales_sum,eu_sales_sum,jp_sales_sum,other_sales_sum]},index=['NA','EU','JP','Other']);
plot = pie_df.plot.pie(y='regional_sales', figsize=(5, 5))
plt.show()
sales_per_year = ea.groupby('Year')['Global_Sales'].nunique().plot(kind='bar')

# %%
#Most of EA's market is in North America
#Globally, EA sold the most number of units in 2008

# %%
activision=df2.loc[df2['Publisher']=="Activision"]
na_sales_sum=activision['NA_Sales'].sum()
eu_sales_sum=activision['EU_Sales'].sum()
jp_sales_sum=activision['JP_Sales'].sum()
other_sales_sum=activision['Other_Sales'].sum()
total_sales_sum=activision['Global_Sales'].sum()
pie_df=pd.DataFrame({'regional_sales':[na_sales_sum,eu_sales_sum,jp_sales_sum,other_sales_sum]},index=['NA','EU','JP','Other']);
plot = pie_df.plot.pie(y='regional_sales', figsize=(5, 5))
plt.show()
sales_per_year = activision.groupby('Year')['Global_Sales'].nunique().plot(kind='bar')

# %%
#Most of Activision's market is in North America
#Globally, Activision sold the most number of units in 2009

# %%
t2i=df2.loc[df2['Publisher']=="Take-Two Interactive"]
na_sales_sum=t2i['NA_Sales'].sum()
eu_sales_sum=t2i['EU_Sales'].sum()
jp_sales_sum=t2i['JP_Sales'].sum()
other_sales_sum=t2i['Other_Sales'].sum()
total_sales_sum=t2i['Global_Sales'].sum()
pie_df=pd.DataFrame({'regional_sales':[na_sales_sum,eu_sales_sum,jp_sales_sum,other_sales_sum]},index=['NA','EU','JP','Other']);
plot = pie_df.plot.pie(y='regional_sales',figsize=(5, 5))
plt.show()
sales_per_year = t2i.groupby('Year')['Global_Sales'].nunique().plot(kind='bar')

# %%
kde=df2.loc[df2['Publisher']=="Konami Digital Entertainment"]
na_sales_sum=kde['NA_Sales'].sum()
eu_sales_sum=kde['EU_Sales'].sum()
jp_sales_sum=kde['JP_Sales'].sum()
other_sales_sum=kde['Other_Sales'].sum()
total_sales_sum=kde['Global_Sales'].sum()
pie_df=pd.DataFrame({'regional_sales':[na_sales_sum,eu_sales_sum,jp_sales_sum,other_sales_sum]},index=['NA','EU','JP','Other']);
plot = pie_df.plot.pie(y='regional_sales',figsize=(5, 5))
plt.show()
sales_per_year = kde.groupby('Year')['Global_Sales'].nunique().plot(kind='bar')

# %%
ubisoft=df2.loc[df2['Publisher']=="Ubisoft"]
na_sales_sum=ubisoft['NA_Sales'].sum()
eu_sales_sum=ubisoft['EU_Sales'].sum()
jp_sales_sum=ubisoft['JP_Sales'].sum()
other_sales_sum=ubisoft['Other_Sales'].sum()
total_sales_sum=ubisoft['Global_Sales'].sum()
pie_df=pd.DataFrame({'regional_sales':[na_sales_sum,eu_sales_sum,jp_sales_sum,other_sales_sum]},index=['NA','EU','JP','Other']);
plot = pie_df.plot.pie(y='regional_sales',figsize=(5, 5))
plt.show()
sales_per_year = ubisoft.groupby('Year')['Global_Sales'].nunique().plot(kind='bar')

# %%
thq=df2.loc[df2['Publisher']=="THQ"]
na_sales_sum=thq['NA_Sales'].sum()
eu_sales_sum=thq['EU_Sales'].sum()
jp_sales_sum=thq['JP_Sales'].sum()
other_sales_sum=thq['Other_Sales'].sum()
total_sales_sum=thq['Global_Sales'].sum()
pie_df=pd.DataFrame({'regional_sales':[na_sales_sum,eu_sales_sum,jp_sales_sum,other_sales_sum]},index=['NA','EU','JP','Other']);
plot = pie_df.plot.pie(y='regional_sales',figsize=(5, 5))
plt.show()
sales_per_year = thq.groupby('Year')['Global_Sales'].nunique().plot(kind='bar')

# %%
sega=df2.loc[df2['Publisher']=="Sega"]
na_sales_sum=sega['NA_Sales'].sum()
eu_sales_sum=sega['EU_Sales'].sum()
jp_sales_sum=sega['JP_Sales'].sum()
other_sales_sum=sega['Other_Sales'].sum()
total_sales_sum=sega['Global_Sales'].sum()
pie_df=pd.DataFrame({'regional_sales':[na_sales_sum,eu_sales_sum,jp_sales_sum,other_sales_sum]},index=['NA','EU','JP','Other']);
plot = pie_df.plot.pie(y='regional_sales',figsize=(5, 5))
plt.show()
sales_per_year = sega.groupby('Year')['Global_Sales'].nunique().plot(kind='bar')

# %%
msgs=df2.loc[df2['Publisher']=="Microsoft Game Studios"]
na_sales_sum=msgs['NA_Sales'].sum()
eu_sales_sum=msgs['EU_Sales'].sum()
jp_sales_sum=msgs['JP_Sales'].sum()
other_sales_sum=msgs['Other_Sales'].sum()
total_sales_sum=msgs['Global_Sales'].sum()
pie_df=pd.DataFrame({'regional_sales':[na_sales_sum,eu_sales_sum,jp_sales_sum,other_sales_sum]},index=['NA','EU','JP','Other']);
plot = pie_df.plot.pie(y='regional_sales',figsize=(5, 5))
plt.show()
sales_per_year = msgs.groupby('Year')['Global_Sales'].nunique().plot(kind='bar')

# %%
pokemon=df2.loc[df2['Name'].str.contains('Pokemon')]
pokemon.append(df2.loc[df2['Name'].str.contains('Pokémon')])
pokemon.sort_values(by='Rank')
# Out:
#         Rank                                               Name Platform  \
# 4          5                           Pokemon Red/Pokemon Blue       GB
# 12        13                        Pokemon Gold/Pokemon Silver       GB
# 20        21                      Pokemon Diamond/Pokemon Pearl       DS
# 25        26                      Pokemon Ruby/Pokemon Sapphire      GBA
# 26        27                        Pokemon Black/Pokemon White       DS
# 32        33                                Pokemon X/Pokemon Y      3DS
# 45        46               Pokemon HeartGold/Pokemon SoulSilver       DS
# 49        50          Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS
# 58        59                  Pokemon FireRed/Pokemon LeafGreen      GBA
# 81        82                    Pokemon Black 2/Pokemon White 2       DS
# 165      166                                    Pokemon Stadium      N64
# 171      172                                    Pokemon Pinball       GB
# 209      210  Pokemon Mystery Dungeon: Explorers of Time/Exp...       DS
# 346      347                                       Pokemon Snap      N64
# 692      694                   Pokemon Ranger: Shadows of Almia       DS
# 750      752                                     Pokemon Ranger       DS
# 816      818      Pokemon Mystery Dungeon: Red/Blue Rescue Team      GBA
# 1139    1141                          Pokemon Battle Revolution      Wii
# 1178    1180          Pokemon Mystery Dungeon: Explorers of Sky       DS
# 1192    1194                   Pokemon Pinball: Ruby & Sapphire      GBA
# 1481    1483                     Pokemon Ranger: Guardian Signs       DS
# 1555    1557         Pokemon Mystery Dungeon: Gates to Infinity      3DS
# 1591    1593                       Pokemon XD: Gale of Darkness       GC
# 1702    1704                      Pokemon Super Mystery Dungeon      3DS
# 1781    1783                               Pokemon Rumble Blast      3DS
# 1986    1988                                   Pokemon Conquest       DS
# 2336    2338              Pokemon Card GB2: Here Comes Team GR!       GB
# 2681    2683                                       Pokemon Dash       DS
# 3381    3383                                    Pokemon Trozei!       DS
# 4044    4046                                Pokemon Art Academy      3DS
# 4365    4367                              Pokemon Puzzle League      N64
# 5050    5052                                    Pokemon Channel       GC
# 6098    6100                    Battle & Get! Pokemon Typing DS       DS
# 6231    6233                       Pokemon Box: Ruby & Sapphire       GC
# 10992  10994                               Pokemon Rumble World      3DS
#
#          Year         Genre Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 4      1996.0  Role-Playing  Nintendo     11.27      8.89     10.22
# 12     1999.0  Role-Playing  Nintendo      9.00      6.18      7.20
# 20     2006.0  Role-Playing  Nintendo      6.42      4.52      6.04
# 25     2002.0  Role-Playing  Nintendo      6.06      3.90      5.38
# 26     2010.0  Role-Playing  Nintendo      5.57      3.28      5.65
# 32     2013.0  Role-Playing  Nintendo      5.17      4.05      4.34
# 45     2009.0        Action  Nintendo      4.40      2.77      3.96
# 49     2014.0  Role-Playing  Nintendo      4.23      3.37      3.08
# 58     2004.0  Role-Playing  Nintendo      4.34      2.65      3.15
# 81     2012.0  Role-Playing  Nintendo      2.91      1.86      3.14
# 165    1999.0      Strategy  Nintendo      3.18      1.24      0.94
# 171    1999.0          Misc  Nintendo      3.02      1.12      1.01
# 209    2007.0  Role-Playing  Nintendo      1.85      1.20      1.54
# 346    1999.0    Simulation  Nintendo      2.23      0.68      0.66
# 692    2008.0  Role-Playing  Nintendo      0.95      0.54      0.62
# 750    2006.0  Role-Playing  Nintendo      1.29      0.04      0.73
# 816    2005.0  Role-Playing  Nintendo      0.71      0.52      0.74
# 1139   2006.0  Role-Playing  Nintendo      0.80      0.38      0.30
# 1178   2009.0  Role-Playing  Nintendo      0.58      0.44      0.44
# 1192   2003.0          Misc  Nintendo      0.68      0.38      0.44
# 1481   2010.0  Role-Playing  Nintendo      0.51      0.17      0.58
# 1555   2012.0  Role-Playing  Nintendo      0.44      0.30      0.47
# 1591   2005.0  Role-Playing  Nintendo      0.71      0.19      0.31
# 1702   2015.0  Role-Playing  Nintendo      0.46      0.31      0.33
# 1781   2011.0        Action  Nintendo      0.47      0.26      0.35
# 1986   2012.0  Role-Playing  Nintendo      0.58      0.06      0.37
# 2336   2001.0      Strategy  Nintendo      0.00      0.00      0.89
# 2681   2004.0        Racing  Nintendo      0.21      0.14      0.38
# 3381   2005.0        Puzzle  Nintendo      0.26      0.00      0.31
# 4044   2014.0          Misc  Nintendo      0.18      0.12      0.16
# 4365   2000.0        Puzzle  Nintendo      0.36      0.08      0.00
# 5050   2003.0     Adventure  Nintendo      0.24      0.06      0.07
# 6098   2011.0          Misc  Nintendo      0.00      0.00      0.29
# 6231   2003.0          Misc  Nintendo      0.00      0.00      0.27
# 10992  2015.0        Action  Nintendo      0.00      0.01      0.08
#
#        Other_Sales  Global_Sales
# 4             1.00         31.37
# 12            0.71         23.10
# 20            1.37         18.36
# 25            0.50         15.85
# 26            0.82         15.32
# 32            0.79         14.35
# 45            0.77         11.90
# 49            0.65         11.33
# 58            0.35         10.49
# 81            0.43          8.33
# 165           0.09          5.45
# 171           0.16          5.31
# 209           0.37          4.96
# 346           0.06          3.63
# 692           0.18          2.30
# 750           0.12          2.18
# 816           0.08          2.06
# 1139          0.13          1.61
# 1178          0.12          1.58
# 1192          0.05          1.56
# 1481          0.06          1.33
# 1555          0.06          1.27
# 1591          0.03          1.25
# 1702          0.08          1.19
# 1781          0.07          1.14
# 1986          0.04          1.05
# 2336          0.00          0.89
# 2681          0.04          0.77
# 3381          0.02          0.60
# 4044          0.03          0.49
# 4365          0.01          0.45
# 5050          0.01          0.38
# 6098          0.00          0.29
# 6231          0.01          0.28
# 10992         0.00          0.09

# %%
mario=df2.loc[df2['Name'].str.contains('Mario')]
pokemon.append(df2.loc[df2['Name'].str.contains('Super Smash Bros')])
mario.sort_values(by='Rank')
# Out:
#         Rank                                               Name Platform  \
# 1          2                                  Super Mario Bros.      NES
# 2          3                                     Mario Kart Wii      Wii
# 6          7                              New Super Mario Bros.       DS
# 8          9                          New Super Mario Bros. Wii      Wii
# 11        12                                      Mario Kart DS       DS
# 18        19                                  Super Mario World     SNES
# 21        22                                   Super Mario Land       GB
# 22        23                                Super Mario Bros. 3      NES
# 42        43                                       Mario Kart 7      3DS
# 46        47                                     Super Mario 64      N64
# 48        49                                 Super Mario Galaxy      Wii
# 50        51                 Super Mario Land 2: 6 Golden Coins       GB
# 53        54                                Super Mario 3D Land      3DS
# 57        58                              Super Mario All-Stars     SNES
# 59        60                                     Super Mario 64       DS
# 63        64                                      Mario Kart 64      N64
# 64        65                            New Super Mario Bros. 2      3DS
# 74        75                                     Mario Party DS       DS
# 76        77                                   Super Mario Kart     SNES
# 80        81                                      Mario Party 8      Wii
# 85        86                 Mario & Sonic at the Olympic Games      Wii
# 91        92                               Super Mario Galaxy 2      Wii
# 96        97                                Super Mario Bros. 2      NES
# 108      109                                       Mario Kart 8     WiiU
# 110      111                          Mario Kart: Double Dash!!       GC
# 135      136                               Super Mario Sunshine       GC
# 162      163                                Super Mario Advance      GBA
# 163      164                          Mario Kart: Super Circuit      GBA
# 164      165                                  Super Mario World      GBA
# 170      171                                          Dr. Mario       GB
# ...      ...                                                ...      ...
# 1710    1712                                       Mario Tennis       GB
# 1738    1740                              Mario vs. Donkey Kong      GBA
# 2109    2111                                Mario Party Advance      GBA
# 2204    2206                                  Mario Tennis Open      3DS
# 2590    2592  Mario & Sonic at the Sochi 2014 Olympic Winter...     WiiU
# 2771    2773                           Mario & Luigi: Paper Jam      3DS
# 2954    2956                                 Mario Pinball Land      GBA
# 3271    3273                                    Mario's Picross       GB
# 3568    3570                      Classic NES Series: Dr. Mario      GBA
# 3822    3824                           Mario Tennis: Power Tour      GBA
# 4041    4043                                      Mario & Wario     SNES
# 4091    4093                             Mario Golf: World Tour      3DS
# 4221    4223                  Dance Dance Revolution: Mario Mix       GC
# 4261    4263        Mario & Sonic at the Rio 2016 Olympic Games      3DS
# 4299    4301     Puzzle & Dragons Z + Super Mario Bros. Edition      3DS
# 4400    4402                           Mario Tennis Ultra Smash     WiiU
# 4404    4406                           Mario Golf: Advance Tour      GBA
# 4588    4590                  Famicom Mini: Super Mario Bros. 2      GBA
# 4623    4625                                       Dr. Mario 64      N64
# 4765    4767                             Mario no Super Picross     SNES
# 5567    5569                          Dr. Mario / Puzzle League      GBA
# 5716    5718                                         Mario Golf       GB
# 6588    6590        Mario & Sonic at the Rio 2016 Olympic Games     WiiU
# 11282  11284                          Famicom Mini: Mario Bros.      GBA
# 12123  12125                                       Mario Tennis      Wii
# 12373  12375               Mario vs. Donkey Kong: Tipping Stars      3DS
# 12770  12772       Dance Dance Revolution: Mario Mix (JP sales)       GC
# 13273  13275               Detective Conan: Marionette Symphony      3DS
# 16357  16360               Mario vs. Donkey Kong: Tipping Stars     WiiU
# 16542  16545  Mario & Luigi: Paper Jam & Mario Kart 7 Double...      3DS
#
#          Year         Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
#
# 4299   2015.0        Puzzle            Nintendo      0.05      0.05      0.34
# 4400   2015.0        Sports            Nintendo      0.13      0.16      0.13
# 4404   2004.0        Sports            Nintendo      0.32      0.12      0.00
# 4588   2004.0      Platform            Nintendo      0.00      0.00      0.41
# 4623   2001.0        Puzzle            Nintendo      0.34      0.07      0.00
# 4765   1995.0        Puzzle            Nintendo      0.00      0.00      0.41
# 5567   2005.0        Puzzle            Nintendo      0.12      0.04      0.16
# 5716   1999.0        Action            Nintendo      0.00      0.00      0.31
# 6588   2016.0        Action            Nintendo      0.03      0.11      0.10
# 11282  2004.0      Platform            Nintendo      0.00      0.00      0.08
# 12123  2010.0        Sports            Nintendo      0.00      0.06      0.00
# 12373  2015.0        Puzzle            Nintendo      0.00      0.00      0.06
# 12770  2005.0    Simulation            Nintendo      0.00      0.00      0.05
# 13273  2013.0     Adventure  Namco Bandai Games      0.00      0.00      0.05
# 16357  2015.0        Puzzle            Nintendo      0.00      0.00      0.01
# 16542  2015.0          Misc            Nintendo      0.00      0.00      0.01
#
#        Other_Sales  Global_Sales
# 1             0.77         40.24
# 2             3.31         35.82
# 6             2.90         30.01
# 8             2.26         28.62
# 11            1.92         23.42
# 18            0.55         20.61
# 21            0.42         18.14
# 22            0.46         17.28
# 42            0.89         12.21
# 46            0.23         11.89
# 48            0.76         11.52
# 50            0.29         11.18
# 53            0.78         10.79
# 57            0.29         10.55
# 59            0.98         10.42
# 63            0.15          9.87
# 64            0.63          9.82
# 74            0.70          9.02
# 76            0.18          8.76
# 80            0.73          8.42
# 85            0.91          8.06
# 91            0.64          7.69
# 96            0.19          7.46
# 108           0.49          6.96
# 110           0.19          6.95
# 135           0.17          6.31
# 162           0.20          5.49
# 163           0.23          5.47
# 164           0.20          5.46
# 170           0.20          5.34
# ...            ...           ...
# 1710          0.06          1.18
# 1738          0.02          1.17
# 2109          0.02          0.98
# 2204          0.05          0.94
# 2590          0.06          0.80
# 2771          0.04          0.74
# 2954          0.01          0.69
# 3271          0.00          0.62
# 3568          0.01          0.56
# 3822          0.01          0.52
# 4041          0.00          0.49
# 4091          0.03          0.48
# 4221          0.01          0.47
# 4261          0.01          0.46
# 4299          0.01          0.46
# 4400          0.03          0.45
# 4404          0.01          0.45
# 4588          0.01          0.42
# 4623          0.00          0.42
# 4765          0.00          0.41
# 5567          0.01          0.33
# 5716          0.00          0.31
# 6588          0.01          0.26
# 11282         0.00          0.08
# 12123         0.01          0.07
# 12373         0.00          0.06
# 12770         0.00          0.06
# 13273         0.00          0.05
# 16357         0.00          0.01
# 16542         0.00          0.01
#
# [112 rows x 11 columns]

# %%
p_sample=pokemon.sample(frac =.25)
m_sample=mario.sample(frac =.25)
from statsmodels.stats import weightstats as stests
#H0: Pokemon and Mario games have equal mean global sales
#H1: Pokemon and Mario games don't have equal mean global sales
ztest ,pval = stests.ztest(p_sample['Global_Sales'], x2=m_sample['Global_Sales'], value=0,alternative='two-sided')
print('P-value: ',float(pval))
if pval<0.05:
    print("reject null hypothesis")
else:
    print("fail to reject null hypothesis")
# Out:
# P-value:  0.7932227389628839
# fail to reject null hypothesis
